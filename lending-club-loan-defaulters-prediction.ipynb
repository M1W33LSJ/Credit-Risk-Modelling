# %% [markdown]
# # 🏦 Credit Risk Problem Statement
#
# # 📑 Introduction
#
# > `LendingClub` is a US peer-to-peer lending company, headquartered in San Francisco, California. It was the first peer-to-peer lender to register its offerings as securities with the Securities and Exchange Commission (SEC), and to offer loan trading on a secondary market. `LendingClub` is the world's largest peer-to-peer lending platform.
#
# > Solving this case study will give us an idea about how real business problems are solved using EDA and Machine Learning. In this case study, we will also develop a basic understanding of risk analytics in banking and financial services and understand how data is used to minimise the risk of losing money while lending to customers.
#
# # 📝 Business Understanding
#
# > You work for the `LendingClub` company which specialises in lending various types of loans to urban customers. When the company receives a loan application, the company has to make a decision for loan approval based on the applicant’s profile. Two types of risks are associated with the bank’s decision:
#
# > - If the applicant is likely to repay the loan, then not approving the loan results in a loss of business to the company
# > - If the applicant is not likely to repay the loan, i.e. he/she is likely to default, then approving the loan may lead to a financial loss for the company
#
# > The data given contains the information about past loan applicants and whether they ‘defaulted’ or not. The aim is to identify patterns which indicate if a person is likely to default, which may be used for takin actions such as denying the loan, reducing the amount of loan, lending (to risky applicants) at a higher interest rate, etc.
#
# > When a person applies for a loan, there are two types of decisions that could be taken by the company:
# > 1. `Loan accepted`: If the company approves the loan, there are 3 possible scenarios described below:
#     - `Fully paid`: Applicant has fully paid the loan (the principal and the interest rate)
#     - `Current`: Applicant is in the process of paying the instalments, i.e. the tenure of the loan is not yet completed. These candidates are not labelled as 'defaulted'.
#     - `Charged-off`: Applicant has not paid the instalments in due time for a long period of time, i.e. he/she has defaulted on the loan
# > 2. `Loan rejected`: The company had rejected the loan (because the candidate does not meet their requirements etc.). Since the loan was rejected, there is no transactional history of those applicants with the company and so this data is not available with the company (and thus in this dataset)
#
# # 🎯 Business Objectives
# > - `LendingClub` is the largest online loan marketplace, facilitating personal loans, business loans, and financing of medical procedures. Borrowers can easily access lower interest rate loans through a fast online interface.
# > - Like most other lending companies, lending loans to ‘`risky`’ applicants is the largest source of financial loss (called `credit loss`). The credit loss is the amount of money lost by the lender when the borrower refuses to pay or runs away with the money owed. In other words, borrowers who defaultcause the largest amount of loss to the lenders. In this case, the customers labelled as '`charged-off`' are the '`defaulters`'.
# > - If one is able to identify these risky loan applicants, then such loans can be reduced thereby cutting down the amount of credit loss. Identification of such applicants using EDA and machine learning is the aim of this case study.
# > - In other words, the company wants to understand the driving factors (or driver variables) behind loan default, i.e. the variables which are strong indicators of default. The company can utilise this knowledge for its portfolio and risk assessment.
# > - To develop your understanding of the domain, you are advised to independently research a little about risk analytics (understanding the types of variables and their significance should be enough).
#
# # 💾 Data Description
#
# ----
# -----
# Here is the information on this particular data set:
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LoanStatNew</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>loan_amnt</td>
#       <td>The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>term</td>
#       <td>The number of payments on the loan. Values are in months and can be either 36 or 60.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>int_rate</td>
#       <td>Interest Rate on the loan</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>installment</td>
#       <td>The monthly payment owed by the borrower if the loan originates.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>grade</td>
#       <td>LC assigned loan grade</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>sub_grade</td>
#       <td>LC assigned loan subgrade</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>emp_title</td>
#       <td>The job title supplied by the Borrower when applying for the loan.*</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>emp_length</td>
#       <td>Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>home_ownership</td>
#       <td>The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>annual_inc</td>
#       <td>The self-reported annual income provided by the borrower during registration.</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>verification_status</td>
#       <td>Indicates if income was verified by LC, not verified, or if the income source was verified</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>issue_d</td>
#       <td>The month which the loan was funded</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>loan_status</td>
#       <td>Current status of the loan</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>purpose</td>
#       <td>A category provided by the borrower for the loan request.</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>title</td>
#       <td>The loan title provided by the borrower</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>zip_code</td>
#       <td>The first 3 numbers of the zip code provided by the borrower in the loan application.</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>addr_state</td>
#       <td>The state provided by the borrower in the loan application</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>dti</td>
#       <td>A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>earliest_cr_line</td>
#       <td>The month the borrower's earliest reported credit line was opened</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>open_acc</td>
#       <td>The number of open credit lines in the borrower's credit file.</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>pub_rec</td>
#       <td>Number of derogatory public records</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>revol_bal</td>
#       <td>Total credit revolving balance</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>revol_util</td>
#       <td>Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>total_acc</td>
#       <td>The total number of credit lines currently in the borrower's credit file</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>initial_list_status</td>
#       <td>The initial listing status of the loan. Possible values are – W, F</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>application_type</td>
#       <td>Indicates whether the loan is an individual application or a joint application with two co-borrowers</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>mort_acc</td>
#       <td>Number of mortgage accounts.</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>pub_rec_bankruptcies</td>
#       <td>Number of public record bankruptcies</td>
#     </tr>
#   </tbody>
# </table>
#
# ---
# ----

# %% [markdown]
# # DTI means debt-to-income ratio.
# - Lower DTI means that there is more income available to cover new expenses.
# - Higher DTI means that there is less income available to cover new expenses.

# %% [markdown]
# # Revolving balance the amount that is owned on a credit card that is unpaid at the end of billing cycle.

# %% [markdown]
# # Derogatory market records are negative entries on a credit report, such as late payments, bankruptcies, and foreclosures, that indicate a borrower may be a financial risk.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats 
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import (
    accuracy_score, confusion_matrix, classification_report, 
    roc_auc_score, roc_curve, auc
)
from sklearn.metrics import ConfusionMatrixDisplay, RocCurveDisplay

from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

pd.set_option('display.float', '{:.2f}'.format)
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)

# %%
data = pd.read_csv("lending_club_loan_two.csv")
data.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0   10000.00   36 months     11.44       329.48     B        B4
# 1    8000.00   36 months     11.99       265.68     B        B5
# 2   15600.00   36 months     10.49       506.97     B        B3
# 3    7200.00   36 months      6.49       220.65     A        A2
# 4   24375.00   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  \
# 0                Marketing  10+ years           RENT   117000.00
# 1          Credit analyst     4 years       MORTGAGE    65000.00
# 2             Statistician   < 1 year           RENT    43057.00
# 3          Client Advocate    6 years           RENT    54000.00
# 4  Destiny Management Inc.    9 years       MORTGAGE    55000.00
#
#   verification_status   issue_d  loan_status             purpose  \
# 0        Not Verified  Jan-2015   Fully Paid            vacation
# ...

# %%
data.describe()
# Out:
#        loan_amnt  int_rate  installment  annual_inc       dti  open_acc  \
# count  396030.00 396030.00    396030.00   396030.00 396030.00 396030.00
# mean    14113.89     13.64       431.85    74203.18     17.38     11.31
# std      8357.44      4.47       250.73    61637.62     18.02      5.14
# min       500.00      5.32        16.08        0.00      0.00      0.00
# 25%      8000.00     10.49       250.33    45000.00     11.28      8.00
# 50%     12000.00     13.33       375.43    64000.00     16.91     10.00
# 75%     20000.00     16.49       567.30    90000.00     22.98     14.00
# max     40000.00     30.99      1533.81  8706582.00   9999.00     90.00
#
#         pub_rec  revol_bal  revol_util  total_acc  mort_acc  \
# count 396030.00  396030.00   395754.00  396030.00 358235.00
# mean       0.18   15844.54       53.79      25.41      1.81
# std        0.53   20591.84       24.45      11.89      2.15
# min        0.00       0.00        0.00       2.00      0.00
# ...

# %% [markdown]
# # 🔍 Exploratory Data Analysis
#
# > **OVERALL GOAL:**
# > - Get an understanding for which variables are important, view summary statistics, and visualize the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %% [markdown]
# ## ✔️ `loan_status`
#
# > Current status of the loan

# %%
sns.set_style("whitegrid")
sns.countplot(data, x='loan_status',stat='percent')
plt.ylabel('Frequency in %')
plt.xlabel('Status of the loan')
plt.title('Frequency of status of the loans')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.select_dtypes(include=np.number).corr(), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ### 📌 Notice
# > We noticed almost perfect correlation between "`loan_amnt`" the "`installment`" feature. We'll explore this features further. Print out their descriptions and perform a scatterplot between them.
#
# > - It makes sense as the installment would be mostly determined by amount of money borrowed.

# %% [markdown]
# ## ✔️ `loan_amnt` & `installment`
#
# > - `installment`: The monthly payment owed by the borrower if the loan originates.
# > - `loan_amnt`: The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.

# %%
data.groupby(by='loan_status')['loan_amnt'].describe()
# Out:
#                 count     mean     std     min     25%      50%      75%  \
# loan_status
# Charged Off  77673.00 15126.30 8505.09 1000.00 8525.00 14000.00 20000.00
# Fully Paid  318357.00 13866.88 8302.32  500.00 7500.00 12000.00 19225.00
#
#                  max
# loan_status
# Charged Off 40000.00
# Fully Paid  40000.00

# %%
data.groupby(by='loan_status')['installment'].describe()
# Out:
#                 count   mean    std   min    25%    50%    75%     max
# loan_status
# Charged Off  77673.00 452.70 249.10 21.62 274.86 399.06 585.67 1527.00
# Fully Paid  318357.00 426.76 250.86 16.08 244.46 369.51 562.89 1533.81

# %% [markdown]
# ## ✔️ `grade` & `sub_grade`
#
# > - `grade`: LC assigned loan grade
# > - `sub_grade`: LC assigned loan subgrade
#
# Let's explore the Grade and SubGrade columns that LendingClub attributes to the loans.
#
# What are the unique possible `grade` & `sub_grade`?

# %%
print(f"GRADE unique: {data.grade.unique()}")
print(f"SUB_GRADE unique: {data.sub_grade.unique()}")
# Out:
# GRADE unique: ['B' 'A' 'C' 'E' 'D' 'F' 'G']
# SUB_GRADE unique: ['B4' 'B5' 'B3' 'A2' 'C5' 'C3' 'A1' 'B2' 'C1' 'A5' 'E4' 'A4' 'A3' 'D1'
#  'C2' 'B1' 'D3' 'D5' 'D2' 'E1' 'E2' 'E5' 'F4' 'E3' 'D4' 'G1' 'F5' 'G2'
#  'C4' 'F1' 'F3' 'G5' 'G4' 'F2' 'G3']

# %%
grade = sorted(data.grade.unique().tolist())
sns.countplot(data, x='grade', hue='loan_status', order=grade, stat='percent')
# Out:
# <Axes: xlabel='grade', ylabel='percent'>

# %%
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
grade = sorted(data.grade.unique().tolist())
sns.countplot(x='grade', data=data, hue='loan_status', order=grade)

plt.subplot(2, 2, 2)
sub_grade = sorted(data.sub_grade.unique().tolist())
g = sns.countplot(x='sub_grade', data=data, hue='loan_status', order=sub_grade)
g.set_xticklabels(g.get_xticklabels(), rotation=90);
# Out:
# C:\Users\pilka\AppData\Local\Temp\ipykernel_22488\121092049.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %% [markdown]
# It looks like `F` and `G` subgrades don't get paid back that often. Isloate those and recreate the countplot just for those subgrades.

# %%
df = data[(data.grade == 'F') | (data.grade == 'G')]

plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
grade = sorted(df.grade.unique().tolist())
sns.countplot(x='grade', data=df, hue='loan_status', order=grade)

plt.subplot(2, 2, 2)
sub_grade = sorted(df.sub_grade.unique().tolist())
sns.countplot(x='sub_grade', data=df, hue='loan_status', order=sub_grade)
# Out:
# <Axes: xlabel='sub_grade', ylabel='count'>

# %% [markdown]
# ## ✔️ `term`, `home_ownership`, `verification_status` & `purpose`
#
# > - `term`: The number of payments on the loan. Values are in months and can be either 36 or 60.
# > - `home_ownership`: The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER
# > - `verification_status`: Indicates if income was verified by LC, not verified, or if the income source was verified
# > - `purpose`: A category provided by the borrower for the loan request.

# %%
data['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    198348
# RENT        159790
# OWN          37746
# OTHER          112
# NONE            31
# ANY              3
# Name: count, dtype: int64

# %%
data.loc[(data.home_ownership == 'ANY') | (data.home_ownership == 'NONE'), 'home_ownership'] = 'OTHER'  
data.home_ownership.value_counts()
# Out:
# home_ownership
# MORTGAGE    198348
# RENT        159790
# OWN          37746
# OTHER          146
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15, 20))

plt.subplot(4, 2, 1)
sns.countplot(x='term', data=data, hue='loan_status')

plt.subplot(4, 2, 2)
sns.countplot(x='home_ownership', data=data, hue='loan_status')

plt.subplot(4, 2, 3)
sns.countplot(x='verification_status', data=data, hue='loan_status')

plt.subplot(4, 2, 4)
g = sns.countplot(x='purpose', data=data, hue='loan_status')
g.set_xticklabels(g.get_xticklabels(), rotation=90);
# Out:
# C:\Users\pilka\AppData\Local\Temp\ipykernel_22488\2424757870.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %%
data.loc[data['home_ownership']=='OTHER', 'loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     123
# Charged Off     23
# Name: count, dtype: int64

# %% [markdown]
# ## ✔️ `int_rate` & `annual_inc`
#
# > - `int_rate`: Interest Rate on the loan
# > - `annual_inc`: The self-reported annual income provided by the borrower during registration

# %%
sns.boxplot(data, y='int_rate', x='loan_status')
# Out:
# <Axes: xlabel='loan_status', ylabel='int_rate'>

# %%
sns.histplot(data[data.annual_inc <= 250000], x='annual_inc', hue='loan_status')
# Out:
# <Axes: xlabel='annual_inc', ylabel='Count'>

# %%
sns.histplot(data[data.annual_inc > 250000], x='annual_inc', hue='loan_status')
# Out:
# <Axes: xlabel='annual_inc', ylabel='Count'>

# %%
print(f'Clients with income bigger than 250000: {data[data.annual_inc >= 250000].shape[0]}')
print(f'All clients: {data.shape[0]}')
# Out:
# Clients with income bigger than 250000: 4077
# All clients: 396030

# %%
print((data[data.annual_inc >= 250000].shape[0] / data.shape[0]) * 100)
print((data[data.annual_inc >= 1000000].shape[0] / data.shape[0]) * 100)
# Out:
# 1.0294674645860162
# 0.018937959245511705

# %%
def parse_term(s):
    try:
        return int(str(s).strip().split()[0])
    except Exception:
        return np.nan

# %%
data['term_months'] = data.get('term').apply(parse_term) if 'term' in data.columns else np.nan

# %% [markdown]
# ## ✔️ Analysis of ROI

# %%
def roi(loan_amt, annual_rate, n_months, monthly_payment=None):
    # returns ROI = (total_interest_paid_over_term) / principal
    # prefer an existing monthly_payment (e.g., `installment`) when provided
    try:
        loan_amt = float(loan_amt)
    except Exception:
        return np.nan
    if pd.isna(n_months) or n_months <= 0:
        return np.nan
    n = int(n_months)
    r = float(annual_rate)/12.0 if not pd.isna(annual_rate) else 0.0

    # use provided monthly_payment if available
    if monthly_payment is not None and not pd.isna(monthly_payment):
        try:
            payment = float(monthly_payment)
        except Exception:
            payment = None
    else:
        payment = None

    # compute payment from formula if not provided
    if payment is None:
        if r == 0:
            payment = loan_amt / n
        else:
            try:
                payment = loan_amt * (r * (1+r)**n) / ((1+r)**n - 1)
            except Exception:
                return np.nan

    total_paid = payment * n
    # interest over full term = total_paid - principal
    interest_paid = total_paid - loan_amt
    return interest_paid / loan_amt

# %%
data['roi'] = data.apply(
        lambda r: roi(r.get('loan_amnt', np.nan), r['int_rate'], r['term_months'], r.get('installment', np.nan)),
        axis=1
    )

# %%
data['interest_paid'] = data['roi']*data['loan_amnt']

# %%
High_income_clients = data[data.annual_inc >= 250000]
HI_defaults = High_income_clients[High_income_clients.loan_status == 'Charged_off']
HI_non_defaults = High_income_clients[High_income_clients.loan_status == 'Fully Paid']

Lower_income_clients = data[data.annual_inc < 250000]
LI_defaults = Lower_income_clients[Lower_income_clients.loan_status == 'Charged_off']
LI_non_defaults = Lower_income_clients[Lower_income_clients.loan_status == 'Fully Paid']

# %%
sns.boxplot(HI_non_defaults, y='roi')
# Out:
# <Axes: ylabel='roi'>

# %%
sns.boxplot(LI_non_defaults, y='roi')
# Out:
# <Axes: ylabel='roi'>

# %%
data[(data.roi < 0) & (data.initial_list_status == 'w')]
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 216751   15000.00   60 months      6.00       198.91     C        C1
# 231902    9550.00   36 months      6.00       236.11     G        G1
# 256887   14300.00   36 months     12.12       301.97     B        B3
# 359288    7500.00   36 months      6.00       118.47     A        A5
#
#                               emp_title emp_length home_ownership  annual_inc  \
# 216751               Operations Manager    2 years       MORTGAGE    85000.00
# 231902                         operator    3 years           RENT    30000.00
# 256887  Washington County Sheriffs dept  10+ years       MORTGAGE    60000.00
# 359288                     safety Kleen   < 1 year       MORTGAGE    60000.00
#
#        verification_status   issue_d loan_status             purpose  \
# 216751        Not Verified  Aug-2014  Fully Paid         credit_card
# 231902     Source Verified  Aug-2014  Fully Paid         credit_card
# ...

# %% [markdown]
# ### Why there are loans that have negative ROI?
# - Most of them are fractional listings. What that means is that there are more investors paying back the loan.
# - There is exactly 4 records of whole type listing with negative ROI. These loans seem like a mistake from the side of issuer. If these where meant to be whole type listings installment is too low.

# %%
data.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0   10000.00   36 months     11.44       329.48     B        B4
# 1    8000.00   36 months     11.99       265.68     B        B5
# 2   15600.00   36 months     10.49       506.97     B        B3
# 3    7200.00   36 months      6.49       220.65     A        A2
# 4   24375.00   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  \
# 0                Marketing  10+ years           RENT   117000.00
# 1          Credit analyst     4 years       MORTGAGE    65000.00
# 2             Statistician   < 1 year           RENT    43057.00
# 3          Client Advocate    6 years           RENT    54000.00
# 4  Destiny Management Inc.    9 years       MORTGAGE    55000.00
#
#   verification_status   issue_d  loan_status             purpose  \
# 0        Not Verified  Jan-2015   Fully Paid            vacation
# ...

# %%
sns.scatterplot(data[data.loan_status == 'Fully Paid'], x='annual_inc', y='interest_paid')
# Out:
# <Axes: xlabel='annual_inc', ylabel='interest_paid'>

# %%
data.loc[data.annual_inc >= 1000000, 'loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     65
# Charged Off    10
# Name: count, dtype: int64

# %%
data[data.interest_paid == max(data.interest_paid)]
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 196708   40000.00   60 months     29.99      1293.90     F        F3
#
#          emp_title emp_length home_ownership  annual_inc verification_status  \
# 196708  Accountant    5 years       MORTGAGE    85300.00            Verified
#
#          issue_d loan_status           purpose             title   dti  \
# 196708  Oct-2016  Fully Paid  home_improvement  Home improvement 18.20
#
#        earliest_cr_line  open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 196708         Dec-1999     14.00     0.00   29275.00       32.00      23.00
#
#        initial_list_status application_type  mort_acc  pub_rec_bankruptcies  \
# 196708                   w       INDIVIDUAL      3.00                  0.00
#
#                                            address  term_months  roi  \
# 196708  721 Noble Ports\r\nWest Kimberly, NE 70466           60 0.94
#
#         interest_paid
# 196708       37634.00

# %%
data.loc[data.annual_inc >= 250000, 'loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     3509
# Charged Off     568
# Name: count, dtype: int64

# %%
data[data.loan_status == 'Fully Paid'].groupby('grade')[['interest_paid']].sum().sort_values(by='interest_paid', ascending=False)
# Out:
#        interest_paid
# grade
# C       335409835.20
# B       258694500.64
# D       253802951.92
# E       182844791.68
# A        94798552.84
# F        86116449.76
# G        25465704.72

# %%
data[data.loan_status == 'Fully Paid'].groupby('grade')[['roi']].mean().sort_values(by='roi', ascending=False)
# Out:
#        roi
# grade
# G     0.74
# F     0.64
# E     0.50
# D     0.36
# C     0.28
# B     0.19
# A     0.12

# %% [markdown]
# ## ✔️ `emp_title` & `emp_length`
#
# > - `emp_title`: The job title supplied by the Borrower when applying for the loan.
# > - `emp_length`: Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.

# %%
print(data.emp_title.isna().sum())
print(data.emp_title.nunique())
# Out:
# 22927
# 173105

# %%
data['emp_title'].value_counts()[:30]
# Out:
# emp_title
# Teacher                     4389
# Manager                     4250
# Registered Nurse            1856
# RN                          1846
# Supervisor                  1830
# Sales                       1638
# Project Manager             1505
# Owner                       1410
# Driver                      1339
# Office Manager              1218
# manager                     1145
# Director                    1089
# General Manager             1074
# Engineer                     995
# teacher                      962
# driver                       882
# Vice President               857
# Operations Manager           763
# Administrative Assistant     756
# Accountant                   748
# President                    742
# owner                        697
# Account Manager              692
# Police Officer               686
# supervisor                   673
# Attorney                     667
# Sales Manager                665
# sales                        645
# ...

# %%
plt.figure(figsize=(15, 12))

plt.subplot(2, 2, 1)
order = ['< 1 year', '1 year', '2 years', '3 years', '4 years', '5 years', 
          '6 years', '7 years', '8 years', '9 years', '10+ years',]
g = sns.countplot(x='emp_length', data=data, hue='loan_status', order=order)
g.set_xticklabels(g.get_xticklabels(), rotation=90);

plt.subplot(2, 2, 2)
plt.barh(data.emp_title.value_counts()[:30].index, data.emp_title.value_counts()[:30])
plt.title("The most 30 jobs title afforded a loan")
plt.tight_layout()
# Out:
# C:\Users\pilka\AppData\Local\Temp\ipykernel_22488\1777488078.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %% [markdown]
# ## ✔️ `issue_d`, `earliest_cr_line`
#
# > - `issue_d`: The month which the loan was funded
# > - `earliest_cr_line`: The month the borrower's earliest reported credit line was opened

# %%
data['earliest_cr_line'].value_counts()
# Out:
# earliest_cr_line
# Oct-2000    3017
# Aug-2000    2935
# Oct-2001    2896
# Aug-2001    2884
# Nov-2000    2736
#             ...
# Feb-1957       1
# Nov-1950       1
# May-1955       1
# Sep-1961       1
# Nov-1955       1
# Name: count, Length: 684, dtype: int64

# %%
data['issue_d'] = pd.to_datetime(data['issue_d'])
data['earliest_cr_line'] = pd.to_datetime(data['earliest_cr_line'])
# Out:
# C:\Users\pilka\AppData\Local\Temp\ipykernel_22488\836848778.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['issue_d'] = pd.to_datetime(data['issue_d'])
# C:\Users\pilka\AppData\Local\Temp\ipykernel_22488\836848778.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['earliest_cr_line'] = pd.to_datetime(data['earliest_cr_line'])

# %%
sns.histplot(data, x='issue_d', hue='loan_status', bins=35)
# Out:
# <Axes: xlabel='issue_d', ylabel='Count'>

# %% [markdown]
# ## ✔️ `title`
#
# > - `title`: The loan title provided by the borrower

# %%
data.title.isna().sum()
# Out:
# np.int64(1756)

# %%
data['title'] = data.title.str.lower()

# %%
data.title.value_counts()[:10]
# Out:
# title
# debt consolidation           168108
# credit card refinancing       51781
# home improvement              17117
# other                         12993
# consolidation                  5583
# major purchase                 4998
# debt consolidation loan        3513
# business                       3017
# medical expenses               2820
# credit card consolidation      2638
# Name: count, dtype: int64

# %% [markdown]
# `title` will be removed because we have the `purpose` column with is generated from it.

# %% [markdown]
# ## ✔️ `dti`, `open_acc`, `revol_bal`, `revol_util`, & `total_acc`
#
# > - `dti`: A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
# > - `open_acc`: The number of open credit lines in the borrower's credit file.
# > - `revol_bal`: Total credit revolving balance
# > - `revol_util`: Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
# > - `total_acc`: The total number of credit lines currently in the borrower's credit file

# %%
data.dti.value_counts()
# Out:
# dti
# 0.00     313
# 14.40    310
# 19.20    302
# 16.80    301
# 18.00    300
#         ...
# 41.38      1
# 49.83      1
# 46.32      1
# 43.98      1
# 40.61      1
# Name: count, Length: 4262, dtype: int64

# %%
sns.histplot(data, x='dti', bins=50)
# Out:
# <Axes: xlabel='dti', ylabel='Count'>

# %%
data[data.dti == 9999]
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 285674    3700.00   36 months     12.59       123.94     C        C2
#
#        emp_title emp_length home_ownership  annual_inc verification_status  \
# 285674       NaN        NaN       MORTGAGE        0.00        Not Verified
#
#           issue_d  loan_status      purpose                    title     dti  \
# 285674 2015-11-01  Charged Off  credit_card  credit card refinancing 9999.00
#
#        earliest_cr_line  open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 285674       1978-08-01      8.00     0.00   10649.00       56.90      20.00
#
#        initial_list_status application_type  mort_acc  pub_rec_bankruptcies  \
# 285674                   f            JOINT      1.00                  0.00
#
#                                            address  term_months  roi  \
# 285674  033 Clark Mountains\r\nBrownfurt, MA 30723           36 0.21
#
#         interest_paid
# 285674         761.84

# %%
print(data[data['dti']>=40].shape)
# Out:
# (296, 30)

# %%
data.loc[data['dti']>=50, 'loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     26
# Charged Off     9
# Name: count, dtype: int64

# %%
sns.histplot(data[data.dti <= 50], x='dti', hue='loan_status', bins=50)
# Out:
# <Axes: xlabel='dti', ylabel='Count'>

# %%
sns.histplot(data, x='open_acc', hue='loan_status', bins=50)
# Out:
# <Axes: xlabel='open_acc', ylabel='Count'>

# %%
sns.histplot(data, x='total_acc', hue='loan_status', bins=50)
# Out:
# <Axes: xlabel='total_acc', ylabel='Count'>

# %%
print(data.shape)
print(data[data.open_acc > 40].shape)
# Out:
# (396030, 30)
# (217, 30)

# %%
print(data.shape)
print(data[data.total_acc > 80].shape)
# Out:
# (396030, 30)
# (266, 30)

# %%
print(data.shape)
print(data[data.revol_util > 120].shape)
# Out:
# (396030, 30)
# (27, 30)

# %% [markdown]
# # Revolving utilization rate
# - Credit card balance/Credit limit
# - The lower the better credit score
#
# *Credit card balance is the total amount owed to the credit card issuer by a cardholder

# %%
sns.histplot(data[data.revol_util<=200], x='revol_util', hue='loan_status')
# Out:
# <Axes: xlabel='revol_util', ylabel='Count'>

# %%
data[data.revol_util > 200]
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 137211    3500.00   36 months     12.49       117.08     B        B4
#
#              emp_title emp_length home_ownership  annual_inc  \
# 137211  Budget Analyst  10+ years           RENT    45000.00
#
#        verification_status    issue_d loan_status             purpose  \
# 137211            Verified 2014-04-01  Fully Paid  debt_consolidation
#
#                      title   dti earliest_cr_line  open_acc  pub_rec  \
# 137211  debt consolidation 14.67       1998-10-01      2.00     0.00
#
#         revol_bal  revol_util  total_acc initial_list_status application_type  \
# 137211    2677.00      892.30       9.00                   f       INDIVIDUAL
#
#         mort_acc  pub_rec_bankruptcies  \
# 137211      0.00                  0.00
#
#                                              address  term_months  roi  \
# 137211  12506 Connie Burg\r\nVelasquezfort, TN 00813           36 0.20
#
# ...

# %%
print(data.shape)
print(data[data.revol_bal > 250000].shape)
# Out:
# (396030, 30)
# (397, 30)

# %%
sns.histplot(data, x='revol_bal', hue='loan_status')
# Out:
# <Axes: xlabel='revol_bal', ylabel='Count'>

# %%
sns.histplot(data[data.revol_bal<=250000], x='revol_bal', hue='loan_status')
# Out:
# <Axes: xlabel='revol_bal', ylabel='Count'>

# %%
data.loc[data.revol_bal > 250000, 'loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     351
# Charged Off     46
# Name: count, dtype: int64

# %% [markdown]
# ## ✔️ `pub_rec`, `initial_list_status`, `application_type`, `mort_acc`, & `pub_rec_bankruptcies`
#
# > - `pub_rec`: Number of derogatory public records
# > - `initial_list_status`: The initial listing status of the loan. Possible values are – W, F
# > - `application_type`: Indicates whether the loan is an individual application or a joint application with two co-borrowers
# > - `mort_acc`: Number of mortgage accounts
# > - `pub_rec_bankruptcies`: Number of public record bankruptcies

# %% [markdown]
# ### Derogatory public records are negative entries on a credit report that signal financial risk, such as bankruptcies, liens, and judgments. They indicate that financial obligations were not met as agreed and can negatively impact your credit score

# %%
data['pub_rec'].value_counts()
# Out:
# pub_rec
# 0.00     338272
# 1.00      49739
# 2.00       5476
# 3.00       1521
# 4.00        527
# 5.00        237
# 6.00        122
# 7.00         56
# 8.00         34
# 9.00         12
# 10.00        11
# 11.00         8
# 13.00         4
# 12.00         4
# 19.00         2
# 40.00         1
# 17.00         1
# 86.00         1
# 24.00         1
# 15.00         1
# Name: count, dtype: int64

# %%
data[data.pub_rec==86]
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 218818    6400.00   36 months     13.18       216.20     C        C3
#
#        emp_title emp_length home_ownership  annual_inc verification_status  \
# 218818   Teacher     1 year       MORTGAGE    38000.00            Verified
#
#           issue_d  loan_status             purpose               title   dti  \
# 218818 2015-11-01  Charged Off  debt_consolidation  debt consolidation 32.41
#
#        earliest_cr_line  open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 218818       1987-12-01     13.00    86.00    7788.00       78.70      19.00
#
#        initial_list_status application_type  mort_acc  pub_rec_bankruptcies  \
# 218818                   f       INDIVIDUAL      0.00                  1.00
#
#                                                   address  term_months  roi  \
# 218818  32188 Teresa Ridges\r\nEast Kristishire, RI 30723           36 0.22
#
#         interest_paid
# ...

# %%
sns.countplot(data, x='initial_list_status', hue='loan_status')
# Out:
# <Axes: xlabel='initial_list_status', ylabel='count'>

# %%
sns.boxplot(data, x='initial_list_status', y='roi')
# Out:
# <Axes: xlabel='initial_list_status', ylabel='roi'>

# %%
sns.boxplot(data[data.pub_rec<2], x='loan_status', y='pub_rec')
# Out:
# <Axes: xlabel='loan_status', ylabel='pub_rec'>

# %%
sns.countplot(data, x='application_type', hue='loan_status')
# Out:
# <Axes: xlabel='application_type', ylabel='count'>

# %%
sns.countplot(data, x='pub_rec_bankruptcies', hue='loan_status')
# Out:
# <Axes: xlabel='pub_rec_bankruptcies', ylabel='count'>

# %%
sns.boxplot(data, x='loan_status', y='pub_rec_bankruptcies')
# Out:
# <Axes: xlabel='loan_status', ylabel='pub_rec_bankruptcies'>

# %%
def pub_rec(number):
    if number == 0.0:
        return 0
    else:
        return 1
    
def mort_acc(number):
    if number == 0.0:
        return 0
    elif number >= 1.0:
        return 1
    else:
        return number
    
def pub_rec_bankruptcies(number):
    if number == 0.0:
        return 0
    elif number >= 1.0:
        return 1
    else:
        return number

# %%
data['pub_rec'] = data.pub_rec.apply(pub_rec)
data['mort_acc'] = data.mort_acc.apply(mort_acc)
data['pub_rec_bankruptcies'] = data.pub_rec_bankruptcies.apply(pub_rec_bankruptcies)

# %%
plt.figure(figsize=(12, 30))

plt.subplot(6, 2, 1)
sns.countplot(x='pub_rec', data=data, hue='loan_status')

plt.subplot(6, 2, 2)
sns.countplot(x='initial_list_status', data=data, hue='loan_status')

plt.subplot(6, 2, 3)
sns.countplot(x='application_type', data=data, hue='loan_status')

plt.subplot(6, 2, 4)
sns.countplot(x='mort_acc', data=data, hue='loan_status')

plt.subplot(6, 2, 5)
sns.countplot(x='pub_rec_bankruptcies', data=data, hue='loan_status')
# Out:
# <Axes: xlabel='pub_rec_bankruptcies', ylabel='count'>

# %% [markdown]
# ## 📈 How numeric features correlate with the target variable?

# %%
data['loan_status'] = data.loan_status.map({'Fully Paid':0, 'Charged Off':1})

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.select_dtypes(include=np.number).corr(), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ****
# ## Conclusion:
#
# We notice that, there are broadly three types of features:
# - 1. Features related to the applicant (demographic variables such as occupation, employment details etc.),
# - 2. Features related to loan characteristics (amount of loan, interest rate, purpose of loan etc.)
# ****

# %% [markdown]
# # 🔄 Data PreProcessing
#
# **Section Goals:**
# > - Remove or fill any missing data.
# > - Remove unnecessary or repetitive features.
# > - Convert categorical string features to dummy variables.

# %%
# The length of the data
print(f"The Length of the data: {data.shape}")
# Out:
# The Length of the data: (396030, 30)

# %%
# Missing values
for column in data.columns:
    if data[column].isna().sum() != 0:
        missing = data[column].isna().sum()
        portion = (missing / data.shape[0]) * 100
        print(f"'{column}': number of missing values '{missing}' ==> '{portion:.3f}%'")
# Out:
# 'emp_title': number of missing values '22927' ==> '5.789%'
# 'emp_length': number of missing values '18301' ==> '4.621%'
# 'title': number of missing values '1756' ==> '0.443%'
# 'revol_util': number of missing values '276' ==> '0.070%'
# 'mort_acc': number of missing values '37795' ==> '9.543%'
# 'pub_rec_bankruptcies': number of missing values '535' ==> '0.135%'

# %%
data.describe()
# Out:
#        loan_amnt  int_rate  installment  annual_inc  \
# count  396030.00 396030.00    396030.00   396030.00
# mean    14113.89     13.64       431.85    74203.18
# min       500.00      5.32        16.08        0.00
# 25%      8000.00     10.49       250.33    45000.00
# 50%     12000.00     13.33       375.43    64000.00
# 75%     20000.00     16.49       567.30    90000.00
# max     40000.00     30.99      1533.81  8706582.00
# std      8357.44      4.47       250.73    61637.62
#
#                              issue_d  loan_status       dti  \
# count                         396030    396030.00 396030.00
# mean   2014-02-02 15:57:58.045602560         0.20     17.38
# min              2007-06-01 00:00:00         0.00      0.00
# 25%              2013-05-01 00:00:00         0.00     11.28
# 50%              2014-04-01 00:00:00         0.00     16.91
# 75%              2015-03-01 00:00:00         0.00     22.98
# max              2016-12-01 00:00:00         1.00   9999.00
# ...

# %%
data[data.revol_util.isna()].describe()
# Out:
#        loan_amnt  int_rate  installment  annual_inc  \
# count     276.00    276.00       276.00      276.00
# mean    10883.88     15.70       344.02    86930.55
# min       700.00      6.03        23.35     4800.00
# 25%      3825.00     13.08       119.68    41450.00
# 50%      8000.00     15.31       267.75    65731.76
# 75%     15000.00     18.25       468.72   105375.00
# max     40000.00     29.96      1388.45   700000.00
# std      9405.11      4.19       290.80    78356.79
#
#                              issue_d  loan_status    dti  \
# count                            276       276.00 276.00
# mean   2013-08-07 20:46:57.391304448         0.23  14.19
# min              2008-03-01 00:00:00         0.00   0.00
# 25%              2012-11-01 00:00:00         0.00   8.07
# 50%              2013-12-01 00:00:00         0.00  13.88
# 75%              2014-12-08 18:00:00         0.00  20.38
# max              2016-11-01 00:00:00         1.00  39.07
# ...

# %% [markdown]
# ### `emp_title`

# %%
data.emp_title.nunique()
# Out:
# 173105

# %% [markdown]
# Realistically there are too many unique job titles to try to convert this to a dummy variable feature. Let's remove that emp_title column.

# %%
data_clean = data.drop('emp_title', axis=1)

# %% [markdown]
# ### `emp_length`

# %%
data.emp_length.unique()
# Out:
# array(['10+ years', '4 years', '< 1 year', '6 years', '9 years',
#        '2 years', '3 years', '8 years', '7 years', '5 years', '1 year',
#        nan], dtype=object)

# %%
for year in data.emp_length.unique():
    print(f"{year} years in this position:")
    print(f"{data[data.emp_length == year].loan_status.value_counts(normalize=True)}")
    print('==========================================')
# Out:
# 10+ years years in this position:
# loan_status
# 0   0.82
# 1   0.18
# Name: proportion, dtype: float64
# ...
# 4 years years in this position:
# loan_status
# 0   0.81
# 1   0.19
# Name: proportion, dtype: float64
# ...
# < 1 year years in this position:
# loan_status
# 0   0.79
# 1   0.21
# Name: proportion, dtype: float64
# ...
# 6 years years in this position:
# loan_status
# 0   0.81
# 1   0.19
# Name: proportion, dtype: float64
# ...
# 9 years years in this position:
# loan_status
# 0   0.80
# 1   0.20
# Name: proportion, dtype: float64
# ...
# 2 years years in this position:
# loan_status
# 0   0.81
# 1   0.19
# Name: proportion, dtype: float64
# ...
# 3 years years in this position:
# loan_status
# 0   0.80
# 1   0.20
# Name: proportion, dtype: float64
# ...
# 8 years years in this position:
# loan_status
# 0   0.80
# 1   0.20
# Name: proportion, dtype: float64
# ...
# 7 years years in this position:
# loan_status
# 0   0.81
# 1   0.19
# Name: proportion, dtype: float64
# ...
# 5 years years in this position:
# loan_status
# ...

# %% [markdown]
# Charge off rates are extremely similar across all employment lengths. So we are going to drop the `emp_length` column.

# %%
data_clean = data_clean.drop('emp_length', axis=1)

# %% [markdown]
# ### `title`

# %%
data_clean.title.value_counts().head()
# Out:
# title
# debt consolidation         168108
# credit card refinancing     51781
# home improvement            17117
# other                       12993
# consolidation                5583
# Name: count, dtype: int64

# %%
data_clean.purpose.value_counts().head()
# Out:
# purpose
# debt_consolidation    234507
# credit_card            83019
# home_improvement       24030
# other                  21185
# major_purchase          8790
# Name: count, dtype: int64

# %% [markdown]
# The title column is simply a string subcategory/description of the purpose column. So we are going to drop the title column.

# %%
data_clean = data_clean.drop('title', axis=1)

# %% [markdown]
# ### `mort_acc`
#
# There are many ways we could deal with this missing data. We could attempt to build a simple model to fill it in, such as a linear model, we could just fill it in based on the mean of the other columns, or you could even bin the columns into categories and then set NaN as its own category. There is no 100% correct approach!
#
# Let's review the other columns to see which most highly correlates to mort_acc

# %%
data_clean.mort_acc.value_counts()
# Out:
# mort_acc
# 1.00    218458
# 0.00    139777
# Name: count, dtype: int64

# %%
data_clean.mort_acc.isna().sum()
# Out:
# np.int64(37795)

# %%
data_clean
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 0        10000.00   36 months     11.44       329.48     B        B4
# 1         8000.00   36 months     11.99       265.68     B        B5
# 2        15600.00   36 months     10.49       506.97     B        B3
# 3         7200.00   36 months      6.49       220.65     A        A2
# 4        24375.00   60 months     17.27       609.33     C        C5
# ...           ...         ...       ...          ...   ...       ...
# 396025   10000.00   60 months     10.99       217.38     B        B4
# 396026   21000.00   36 months     12.29       700.42     C        C1
# 396027    5000.00   36 months      9.99       161.32     B        B1
# 396028   21000.00   60 months     15.31       503.02     C        C2
# 396029    2000.00   36 months     13.61        67.98     C        C2
#
#        home_ownership  annual_inc verification_status    issue_d  loan_status  \
# ...

# %%
sns.barplot(data_clean.select_dtypes(include=np.number).corr()['mort_acc'].drop('mort_acc').sort_values(), orient='h')
# Out:
# <Axes: xlabel='mort_acc'>

# %% [markdown]
# Looks like the total_acc feature correlates with the mort_acc , this makes sense! Let's try this fillna() approach. We will group the dataframe by the total_acc and calculate the mean value for the mort_acc per total_acc entry. To get the result below:

# %%
total_acc_avg = data_clean.groupby(by='total_acc').mort_acc.mean()

# %%
total_acc_avg
# Out:
# total_acc
# 2.00     0.00
# 3.00     0.05
# 4.00     0.06
# 5.00     0.09
# 6.00     0.12
#          ...
# 124.00   1.00
# 129.00   1.00
# 135.00   1.00
# 150.00   1.00
# 151.00   0.00
# Name: mort_acc, Length: 118, dtype: float64

# %%
def fill_mort_acc(total_acc, mort_acc):
    if np.isnan(mort_acc):
        return total_acc_avg[total_acc].round()
    else:
        return mort_acc

# %%
data_clean['mort_acc'] = data_clean.apply(lambda x: fill_mort_acc(x['total_acc'], x['mort_acc']), axis=1)

# %% [markdown]
# ### `revol_util` & `pub_rec_bankruptcies`
# These two features have missing data points, but they account for less than 0.5% of the total data. So we are going to remove the rows that are missing those values in those columns with dropna().

# %%
for column in data_clean.columns:
    if data_clean[column].isna().sum() != 0:
        missing = data_clean[column].isna().sum()
        portion = (missing / data_clean.shape[0]) * 100
        print(f"'{column}': number of missing values '{missing}' ==> '{portion:.3f}%'")
# Out:
# 'revol_util': number of missing values '276' ==> '0.070%'
# 'pub_rec_bankruptcies': number of missing values '535' ==> '0.135%'

# %%
data_clean = data_clean.dropna()

# %%
data_clean.shape
# Out:
# (395219, 27)

# %% [markdown]
# ## 🧮 Categorical Variables and Dummy Variables

# %%
print([column for column in data_clean.columns if data_clean[column].dtype == object])
# Out:
# ['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status', 'purpose', 'initial_list_status', 'application_type', 'address']

# %% [markdown]
# ### `grade` & `sub_grade`
#
# We know that `grade` is just a sub feature of `sub_grade`, So we are goinig to drop it.

# %%
data_clean = data_clean.drop(['grade','application_type','purpose'], axis=1)

# %% [markdown]
# ### `address`
# We are going to feature engineer a zip code column from the address in the data set. Create a column called 'zip_code' that extracts the zip code from the address column.

# %%
data_clean.address.head()
# Out:
# 0       0174 Michelle Gateway\r\nMendozaberg, OK 22690
# 1    1076 Carney Fort Apt. 347\r\nLoganmouth, SD 05113
# 2    87025 Mark Dale Apt. 269\r\nNew Sabrina, WV 05113
# 3              823 Reid Ford\r\nDelacruzside, MA 00813
# 4               679 Luna Roads\r\nGreggshire, VA 11650
# Name: address, dtype: object

# %%
data_clean['zip_code'] = data_clean.address.apply(lambda x: x[-5:])

# %%
data_clean.zip_code.value_counts()
# Out:
# zip_code
# 70466    56880
# 22690    56413
# 30723    56402
# 48052    55811
# 00813    45725
# 29597    45393
# 05113    45300
# 11650    11210
# 93700    11126
# 86630    10959
# Name: count, dtype: int64

# %%
sns.countplot(data_clean, x='zip_code', hue='loan_status')
# Out:
# <Axes: xlabel='zip_code', ylabel='count'>

# %%
data_clean = data_clean.drop(['address', 'zip_code'], axis=1)

# %% [markdown]
# ### `earliest_cr_line`
# This appears to be a historical time stamp feature. Extract the year from this feature using a `.apply()` function, then convert it to a numeric feature.

# %%
data_clean['earliest_cr_line'] = data_clean.earliest_cr_line.dt.year

# %%
data_clean.earliest_cr_line.nunique()
# Out:
# 65

# %%
data_clean.earliest_cr_line.value_counts()
# Out:
# earliest_cr_line
# 2000    29302
# 2001    29031
# 1999    26444
# 2002    25849
# 2003    23623
#         ...
# 1950        3
# 1951        3
# 1953        2
# 1944        1
# 1948        1
# Name: count, Length: 65, dtype: int64

# %% [markdown]
# ### `term_months`
# Term of loan is categorical variable in this case, as it only includes 36 months or 60 months. It's better to drop term column as it causes problems with multicollinearity.

# %%
data_clean = data_clean.drop('term_months', axis=1)

# %% [markdown]
# ## 🔖 Check for duplicates

# %%
print(f"Data shape: {data.shape}")

data_clean = data_clean.drop_duplicates()

print(f"Data shape: {data.shape}")
# Out:
# Data shape: (396030, 30)
# Data shape: (396030, 30)

# %% [markdown]
# ## 🔪 Train Test Split

# %%
w_p = data_clean.loan_status.value_counts()[0] / data_clean.shape[0]
w_n = data_clean.loan_status.value_counts()[1] / data_clean.shape[0]

print(f"Weight of positive values {w_p}")
print(f"Weight of negative values {w_n}")
# Out:
# Weight of positive values 0.8038474968245374
# Weight of negative values 0.19615250317546265

# %%
# train, test = train_test_split(data_clean, test_size=0.33, random_state=42)

# %% [markdown]
# ### `issue_d`
#
# This would be data leakage, we wouldn't know beforehand whether or not a loan would be issued when using our model, so in theory we wouldn't have an issue_date. We can use this feature to split the data.

# %%
train = data_clean[data_clean.issue_d <= '2014-12-31']
test = data_clean[data_clean.issue_d > '2014-12-31']
train = train.drop('issue_d', axis=1)
test = test.drop('issue_d', axis=1)

# %%
print(train.shape)
train = train[train['annual_inc'] <= 250000]
train = train[train['dti'] <= 50]
train = train[train['open_acc'] <= 40]
train = train[train['total_acc'] <= 80]
train = train[train['revol_util'] <= 120]
train = train[train['revol_bal'] <= 250000]
print(train.shape)
# Out:
# (272935, 21)
# (270620, 21)

# %%
y_train = train.loan_status
X_train = train.drop(['loan_status', 'roi', 'interest_paid',
                      'installment', 'int_rate', 'earliest_cr_line',
                        'dti', 'total_acc', 'pub_rec_bankruptcies'], axis=1)

# %%
y_test = test.loan_status

X_test = test.drop(['loan_status', 'roi', 'interest_paid',
                          'installment','int_rate', 'earliest_cr_line',
                            'dti', 'total_acc', 'pub_rec_bankruptcies'], axis=1)

X_test_LogR = test.drop(['loan_status', 'roi', 'interest_paid',
                          'installment', 'int_rate', 'earliest_cr_line',
                            'dti', 'total_acc', 'pub_rec_bankruptcies'], axis=1)

# %%
dummies = ['sub_grade', 'verification_status', 'initial_list_status', 'home_ownership', 'term']
X_test_LogR = pd.get_dummies(X_test_LogR, columns=dummies, drop_first=True, dtype=float)
X_train = pd.get_dummies(X_train, columns=dummies, drop_first=True, dtype=float)

# %%
X_test_RF = pd.get_dummies(X_test, columns=dummies, drop_first=True, dtype=float)

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = X_train.columns

vif_data["VIF"] = [variance_inflation_factor(X_train.values, i)
                          for i in range(len(X_train.columns))]
print(vif_data)
# Out:
#                                 feature  VIF
# 0                             loan_amnt 6.78
# 1                            annual_inc 6.73
# 2                              open_acc 6.69
# 3                               pub_rec 1.23
# 4                             revol_bal 2.91
# 5                            revol_util 8.37
# 6                              mort_acc 4.11
# 7                          sub_grade_A2 1.32
# 8                          sub_grade_A3 1.40
# 9                          sub_grade_A4 1.63
# 10                         sub_grade_A5 1.74
# 11                         sub_grade_B1 1.80
# 12                         sub_grade_B2 2.02
# 13                         sub_grade_B3 2.27
# 14                         sub_grade_B4 2.23
# 15                         sub_grade_B5 2.00
# 16                         sub_grade_C1 2.09
# 17                         sub_grade_C2 2.05
# 18                         sub_grade_C3 2.00
# 19                         sub_grade_C4 1.96
# ...

# %%
vif_data.sort_values(by='VIF', ascending=False)
# Out:
#                                 feature  VIF
# 5                            revol_util 8.37
# 0                             loan_amnt 6.78
# 1                            annual_inc 6.73
# 2                              open_acc 6.69
# 6                              mort_acc 4.11
# 4                             revol_bal 2.91
# 46                  home_ownership_RENT 2.77
# 42         verification_status_Verified 2.53
# 13                         sub_grade_B3 2.27
# 14                         sub_grade_B4 2.23
# 16                         sub_grade_C1 2.09
# 17                         sub_grade_C2 2.05
# 41  verification_status_Source Verified 2.04
# 12                         sub_grade_B2 2.02
# 15                         sub_grade_B5 2.00
# 18                         sub_grade_C3 2.00
# 47                      term_ 60 months 1.98
# 19                         sub_grade_C4 1.96
# 20                         sub_grade_C5 1.91
# 21                         sub_grade_D1 1.80
# ...

# %% [markdown]
# # 🤖 Models Building

# %%
X_train_glm = X_train.values
X_test_glm = X_test_LogR.values
y_train_glm = y_train.values
y_test_glm = y_test.values

X_train_glm = sm.add_constant(X_train_glm)
X_test_glm  = sm.add_constant(X_test_glm)

X_train_glm = X_train_glm.astype(float)
X_test_glm = X_test_glm.astype(float)

# %%
LogReg = sm.Logit(y_train_glm, X_train_glm).fit()

print(LogReg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.438304
#          Iterations 8
#                            Logit Regression Results
# ...
# Dep. Variable:                      y   No. Observations:               270620
# Model:                          Logit   Df Residuals:                   270571
# Method:                           MLE   Df Model:                           48
# Date:                Wed, 26 Nov 2025   Pseudo R-squ.:                 0.08484
# Time:                        13:54:11   Log-Likelihood:            -1.1861e+05
# converged:                       True   LL-Null:                   -1.2961e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.4187      0.078    -44.108      0.000      -3.571      -3.267
# ...

# %%
y_pred = LogReg.predict(X_test_glm)

# %% [markdown]
# ## Obtained predictions are probabilities of default of each client from test dataset. Now I need to calculate LGD and EAD.
# - LGD can be set arbitrarily based on grade of the loan.
# - EAD is a sum of principal and accured interest.

# %%
LGD_MAP = {
    # A
    "A1": 0.30, "A2": 0.32, "A3": 0.34, "A4": 0.36, "A5": 0.38,
    # B
    "B1": 0.40, "B2": 0.42, "B3": 0.44, "B4": 0.46, "B5": 0.48,
    # C
    "C1": 0.50, "C2": 0.52, "C3": 0.54, "C4": 0.56, "C5": 0.58,
    # D
    "D1": 0.60, "D2": 0.62, "D3": 0.64, "D4": 0.66, "D5": 0.68,
    # E
    "E1": 0.70, "E2": 0.72, "E3": 0.74, "E4": 0.76, "E5": 0.78,
    # F
    "F1": 0.80, "F2": 0.82, "F3": 0.84, "F4": 0.86, "F5": 0.88,
    # G
    "G1": 0.90, "G2": 0.92, "G3": 0.94, "G4": 0.96, "G5": 0.98,
}

# %%
EL_df = pd.DataFrame()

EL_df['PD'] = y_pred
EL_df['LGD'] = X_test.sub_grade.map(LGD_MAP).values
EL_df['EAD'] = (X_test['loan_amnt']*(1+X_test['int_rate']*0.5)).values
EL_df['EL'] = EL_df.PD*EL_df.LGD*EL_df.EAD

# %%
sum_EL = sum(EL_df.EL)

# %%
AL_df = pd.DataFrame()

AL_df['PD'] = y_test
AL_df['LGD'] = X_test.sub_grade.map(LGD_MAP).values
AL_df['EAD'] = (X_test['loan_amnt']*(1+X_test['int_rate']*0.5)).values
AL_df['EL'] = AL_df.PD*AL_df.LGD*AL_df.EAD

# %%
sum_AL = sum(AL_df.EL)

# %%
sum_AL - sum_EL
# Out:
# 81214601.61430836

# %%
sum_AL
# Out:
# 2567368535.6649966

# %%
sum_EL
# Out:
# 2486153934.0506883

# %%
from sklearn.calibration import calibration_curve

prob_true, prob_pred = calibration_curve(y_test, y_pred)

plt.figure(figsize=(7, 7))
plt.plot(prob_pred, prob_true, marker='o', label='Model')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Perfect calibration')
plt.xlabel("Predicted frequency of defaults")
plt.ylabel("True frequency of defaults")
plt.title("Calibration Plot (PD Calibration Curve)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Iterpretation of calibration curve
# Model is doing good job of predicting actual defaults.

# %%
def print_score(true, pred, train=True):
    if train:
        clf_report = pd.DataFrame(classification_report(true, pred, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(true, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(true, pred)}\n")
        
    elif train==False:
        clf_report = pd.DataFrame(classification_report(true, pred, output_dict=True))
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(true, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(true, pred)}\n")

# %%
X_train_RF = np.array(X_train).astype(np.float32)
X_test_RF = np.array(X_test_RF).astype(np.float32)
y_train_RF = np.array(y_train).astype(np.float32)
y_test_RF = np.array(y_test).astype(np.float32)

# %% [markdown]
# # ✔️ Random Forest Classifier

# %%
# param_grid = dict(
#     n_estimators=stats.randint(100, 1500),
#     max_depth=stats.randint(10, 100),
#     min_samples_split=stats.randint(1, 10),
#     min_samples_leaf=stats.randint(1, 10),
# )

rf_clf = RandomForestClassifier(n_estimators=100)
# rf_cv = RandomizedSearchCV(
#     rf_clf, param_grid, cv=3, n_iter=60, 
#     scoring='roc_auc', n_jobs=-1, verbose=1
# )
# rf_cv.fit(X_train, y_train)
# best_params = rf_cv.best_params_
# print(f"Best Parameters: {best_params}")
# rf_clf = RandomForestClassifier(**best_params)
rf_clf.fit(X_train_RF, y_train_RF)

y_train_pred = rf_clf.predict(X_train_RF)
y_test_pred = rf_clf.predict(X_test_RF)

print_score(y_train_RF, y_train_pred, train=True)
print_score(y_test_RF, y_test_pred, train=False)
# Out:
# Train Result:
# ...
# Accuracy Score: 100.00%
# _______________________________________________
# CLASSIFICATION REPORT:
#                 0.0      1.0  accuracy  macro avg  weighted avg
# precision      1.00     1.00      1.00       1.00          1.00
# recall         1.00     1.00      1.00       1.00          1.00
# f1-score       1.00     1.00      1.00       1.00          1.00
# support   220547.00 50073.00      1.00  270620.00     270620.00
# _______________________________________________
# Confusion Matrix:
#  [[220547      0]
#  [     7  50066]]
#
# Test Result:
# ...
# Accuracy Score: 77.57%
# _______________________________________________
# CLASSIFICATION REPORT:
#                0.0      1.0  accuracy  macro avg  weighted avg
# precision     0.79     0.47      0.78       0.63          0.72
# recall        0.97     0.08      0.78       0.53          0.78
# f1-score      0.87     0.13      0.78       0.50          0.71
# support   95138.00 27145.00      0.78  122283.00     122283.00
# ...

# %%
disp = ConfusionMatrixDisplay.from_estimator(rf_clf, X_test_RF, y_test_RF, 
                             cmap='Blues', values_format='d', 
                             display_labels=['Default', 'Fully-Paid'])

disp = RocCurveDisplay.from_estimator(rf_clf, X_test_RF, y_test_RF)

# %%
scores_dict['Random Forest'] = {
        'Train': roc_auc_score(y_train, rf_clf.predict(X_train)),
        'Test': roc_auc_score(y_test, rf_clf.predict(X_test)),
    }

# %% [markdown]
# # ✔️ XGBoost Classifier

# %%
# param_grid = dict(
#     n_estimators=stats.randint(10, 500),
#     max_depth=stats.randint(1, 10),
#     learning_rate=stats.uniform(0, 1)
# )

xgb_clf = XGBClassifier(use_label_encoder=False)
# xgb_cv = RandomizedSearchCV(
#     xgb_clf, param_grid, cv=3, n_iter=60, 
#     scoring='roc_auc', n_jobs=-1, verbose=1
# )
# xgb_cv.fit(X_train, y_train)

# best_params = xgb_cv.best_params_
# best_params['tree_method'] = 'gpu_hist'
# # best_params = {'n_estimators': 50, 'tree_method': 'gpu_hist'}
# print(f"Best Parameters: {best_params}")

# xgb_clf = XGBClassifier(**best_params)
xgb_clf.fit(X_train_RF, y_train_RF)

y_train_pred = xgb_clf.predict(X_train_RF)
y_test_pred = xgb_clf.predict(X_test_RF)

print_score(y_train_RF, y_train_pred, train=True)
print_score(y_test_RF, y_test_pred, train=False)
# Out:
# c:\Users\pilka\Desktop\projekty\credit_risk\.venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:02:07] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Train Result:
# ...
# Accuracy Score: 82.57%
# _______________________________________________
# CLASSIFICATION REPORT:
#                 0.0      1.0  accuracy  macro avg  weighted avg
# precision      0.83     0.71      0.83       0.77          0.81
# recall         0.99     0.10      0.83       0.54          0.83
# f1-score       0.90     0.17      0.83       0.54          0.77
# support   220547.00 50073.00      0.83  270620.00     270620.00
# _______________________________________________
# Confusion Matrix:
#  [[218523   2024]
#  [ 45144   4929]]
#
# Test Result:
# ...
# Accuracy Score: 77.72%
# _______________________________________________
# CLASSIFICATION REPORT:
# ...

# %%
disp = ConfusionMatrixDisplay.from_estimator(
    xgb_clf, X_test_RF, y_test_RF, 
    cmap='Blues', values_format='d', 
    display_labels=['Default', 'Fully-Paid']
)

disp = RocCurveDisplay.from_estimator(xgb_clf, X_test_RF, y_test_RF)

# %%
scores_dict['XGBoost'] = {
        'Train': roc_auc_score(y_train, xgb_clf.predict(X_train)),
        'Test': roc_auc_score(y_test, xgb_clf.predict(X_test)),
    }

# %% [markdown]
# # 📊 Comparing Models Prerformance

# %%
# ml_models = {
#     'Random Forest': rf_clf, 
#     'XGBoost': xgb_clf, 
#     'ANNs': model
# }

# for model in ml_models:
#     print(f"{model.upper():{30}} roc_auc_score: {roc_auc_score(y_test, ml_models[model].predict(X_test)):.3f}")
# Out:
# RANDOM FOREST                  roc_auc_score: 0.725
# XGBOOST                        roc_auc_score: 0.734
# ANNS                           roc_auc_score: 0.905

# %%
# scores_df = pd.DataFrame(scores_dict)
# scores_df.hvplot.barh(
#     width=500, height=400, 
#     title="ROC Scores of ML Models", xlabel="ROC Scores", 
#     alpha=0.4, legend='top'
# )
# Out:
# :Bars   [index,Variable]   (value)
